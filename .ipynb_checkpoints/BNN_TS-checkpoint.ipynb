# %%
#*********************@Author: Aniruddh Khera*********************
# About the data: S&P500 companies stock prices from 2010-2016
# Here I analyzed for GOOGLE, we can do it for other
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb  
import numpy as np
import pymc3 as pm
from pymc3.distributions.timeseries import *
import theano
floatX = theano.config.floatX
import warnings
warnings.filterwarnings('ignore')
df = pd.read_csv("nyse/prices-split-adjusted.csv")

# %%
#**********************EXPLORATORY ANALYSIS**********************
#select google
goog = df[df.symbol == 'GOOG']
goog.date = goog.date.convert_objects(convert_dates='coerce')
goog = goog.sort_index(by="date")
goog = goog.set_index("date")
fig, ax = plt.subplots(figsize=(8, 5))
ax.plot(goog['close'], label='Google')
ax.set(xlabel='time', ylabel='Close')
ax.legend();

# %%
# Split data into training & testing
goog_train = goog[goog.index<'2016-12-14']
goog_test = goog[goog.index>='2016-12-14']

# Take log to make variance constant
goog_train['Log close'] = goog_train['close'].apply(lambda x: np.log(x))  
goog_train['Log open'] = goog_train['close'].apply(lambda x: np.log(x))  
goog_test['Log close'] = goog_test['close'].apply(lambda x: np.log(x))  
goog_test['Log open'] = goog_test['close'].apply(lambda x: np.log(x))

# %%
with pm.Model() as model:
    step_size = pm.Exponential('sigma', 50.)
    s = GaussianRandomWalk('s', sd=step_size,
                           shape=len(goog_train['Log close']))

    nu = pm.Exponential('nu', .1)

    r = pm.StudentT('r', nu=nu,
                    lam=pm.math.exp(-2*s),
                    observed=goog_train['Log close'])

# %%
with model:
    trace = pm.sample(nuts_kwargs=dict(target_accept=.9))
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# 100%|██████████| 2500/2500 [14:46<00:00,  2.62it/s]

# %%
pm.traceplot(trace, varnames=['sigma', 'nu', 's'])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1122d1b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1122d0410>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1122f9b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11244bad0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x112486b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1130574d0>]], dtype=object)

# %%
trace[s].shape
# Out:
# (500, 1751)

# %%
fig, ax = plt.subplots()

plt.plot(trace['s'].T, 'b', alpha=.03);
ax.set(title=str(s), xlabel='time', ylabel='log volatility close');

# %%
fig, ax = plt.subplots()
#ax.plot(goog_train['Log close'])
#ax.plot(np.exp(trace[s].T), 'r', alpha=.03)

# %%
fig, ax = plt.subplots()
ax.plot(goog_train['Log close'])

# %%
fig, ax = plt.subplots(figsize=(8, 5))
ax.plot(goog_train['Log close'])
ax.plot(np.exp(trace[s]), 'r', alpha=.03)
ax.set(xlabel='time', ylabel='log close price')
ax.legend(['S&P500', 'stoch vol']);

# %%
goog_train['Log close'].shape[0]
# Out:
# 1750

# %%
# Trying to emulate http://twiecki.github.io/blog/2017/03/14/random-walk-deep-net/
import theano.tensor as tt
interval = 10
def construct_nn(ann_input, ann_output):   
    n_hidden =  5

    # Initialize random weights between each layer
    init_1 = np.random.randn(1, n_hidden).astype(floatX)
    init_2 = np.random.randn(n_hidden, n_hidden).astype(floatX)
    init_out = np.random.randn(n_hidden).astype(floatX)   
    with pm.Model() as neural_network:
    
        # Weights from input to hidden layer   
        step_size = pm.HalfNormal('step_size', 
                                  sd=np.ones(n_hidden), 
                                  shape=n_hidden)
        weights_in_1 = pm.GaussianRandomWalk('w1', 
                                             sd=step_size, 
                                             shape=(interval, 1, n_hidden),
                                             testval=np.tile(init_1, (interval, 1, 1))
                                            )
        weights_in_1_rep = tt.repeat(weights_in_1, 
                                   ann_input.shape[0]//interval, 
                                   axis=0)
        weights_1_2 = pm.Normal('w2', 
                                mu=0, 
                                sd=1., 
                                shape=(1, n_hidden, n_hidden),
                                testval=init_2)
        weights_1_2_rep = tt.repeat(weights_1_2, 
                                   ann_input.shape[0],
                                   axis=0)
        weights_2_out = pm.Normal('w3', 
                                  mu=0, 
                                  sd=1.,
                                  shape=(1, n_hidden),
                                  testval=init_out)
        weights_2_out_rep = tt.repeat(weights_2_out, 
                                      ann_input.shape[0],
                                        axis = 0)
     

        # Build neural-network using tanh activation function
        act_1 =  tt.tanh(tt.batched_dot(ann_input, weights_in_1_rep))
        act_2 =  tt.tanh(tt.batched_dot(act_1, weights_1_2_rep))
        act_out = tt.batched_dot(act_2,weights_2_out_rep)
        out = pm.Normal('out', act_out, observed=ann_output)
    return neural_network

ann_input = theano.shared(np.array(goog_train['Log open']))
ann_output = theano.shared(np.array(goog_train['Log close']))
neural_network = construct_nn(ann_input, ann_output)

# %%
import scipy.optimize
with neural_network:
    map_est = pm.find_MAP(fmin=scipy.optimize.fmin_l_bfgs_b)

plt.plot(map_est['w1'].reshape(interval, 5))

# %%
with neural_network:
    trace = pm.sample(100, tune=500)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
#  22%|██▏       | 132/600 [04:50<26:43,  3.43s/it]

# %%
with neural_network:
    pm.traceplot(trace)

# %%
with neural_network:
    ppc = pm.sample_ppc(trace)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 523.65it/s]

# %%
plt.plot(ppc['out'].mean(axis=0))

# %%
neural_network.out.distribution
# Out:
# $None \sim \text{Normal}(\mathit{mu}=f(f(f(f(f(f(f(f(f(f(array,w1))),f(f(),f(f(f(f(f(f(array,w1)))))))),f(f(w2),f(f(f(f(f(w2)))),f(f(f(f(f(w2)))),f(f(f(w2))))))),f(f(f(f(f(f(array,w1))))),f(f(f(w2))))))),w3)), \mathit{sd}=1.0)$

# %%
import scipy.optimize
with neural_network:
    map_est = pm.find_MAP(fmin=scipy.optimize.fmin_l_bfgs_b)
# Out:
# logp = -38,507:   2%|▏         | 82/5000 [00:00<00:10, 480.43it/s]

# %%
plt.plot(map_est['w1'])
# Out:
# [<matplotlib.lines.Line2D at 0x7f72439ea2e8>,
#  <matplotlib.lines.Line2D at 0x7f72439eaf60>,
#  <matplotlib.lines.Line2D at 0x7f72439ea1d0>,
#  <matplotlib.lines.Line2D at 0x7f7244c46470>,
#  <matplotlib.lines.Line2D at 0x7f7244c46a20>]

# %%
ppc = pm.sample_ppc([map_est], model=neural_network)
print('Accuracy on train data = {:.2f}%'.format((ppc['out'] == goog_train['Log close']).mean() * 100))
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 891.84it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-99-7dd315f225bd> in <module>()
#       1 ppc = pm.sample_ppc([map_est], model=neural_network)
# ----> 2 print('Accuracy on train data = {:.2f}%'.format((ppc['out'] == goog_train['Log close']).mean() * 100))
#
# /home/aniruddh/anaconda3/lib/python3.5/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#     844             if (not is_scalar(lib.item_from_zerodim(other)) and
#     845                     len(self) != len(other)):
# --> 846                 raise ValueError('Lengths must match to compare')
#     847
#     848             if isinstance(other, ABCPeriodIndex):
#
# ValueError: Lengths must match to compare

# %%
ann_input.set_value(goog_test['Log open'])
ann_output.set_value(goog_test['Log close'])
with neural_network:
    ppc = pm.sample_ppc(trace, 500)
    pred = ppc['out'].mean(axis=0)
    proba = ppc['out'].std(axis=0)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/aniruddh/anaconda3/lib/python3.5/site-packages/theano/compile/function_module.py in __call__(self, *args, **kwargs)
#     883             outputs =\
# --> 884                 self.fn() if output_subset is None else\
#     885                 self.fn(output_subset=output_subset)
#
# ValueError: Shape mismatch: A.shape[1] != x.shape[0]
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-102-d4fef539f86f> in <module>()
#       2 ann_output.set_value(goog_test['Log close'])
#       3 with neural_network:
# ----> 4     ppc = pm.sample_ppc(trace, 500)
#       5     pred = ppc['out'].mean(axis=0)
#       6     proba = ppc['out'].std(axis=0)
#
# /home/aniruddh/anaconda3/lib/python3.5/site-packages/pymc3/sampling.py in sample_ppc(trace, samples, model, vars, size, random_seed, progressbar)
#     570             for var in vars:
#     571                 ppc[var.name].append(var.distribution.random(point=param,
# --> 572                                                              size=size))
#     573
#     574     except KeyboardInterrupt:
#
# /home/aniruddh/anaconda3/lib/python3.5/site-packages/pymc3/distributions/continuous.py in random(self, point, size, repeat)
#     288     def random(self, point=None, size=None, repeat=None):
#     289         mu, tau, _ = draw_values([self.mu, self.tau, self.sd],
# --> 290                                  point=point)
#     291         return generate_samples(stats.norm.rvs, loc=mu, scale=tau**-0.5,
#     292                                 dist_shape=self.shape,
#
# /home/aniruddh/anaconda3/lib/python3.5/site-packages/pymc3/distributions/distribution.py in draw_values(params, point)
#     219     values = []
#     220     for param in params:
# --> 221         values.append(_draw_value(param, point=point, givens=givens.values()))
#     222     return values
#     223
#
# /home/aniruddh/anaconda3/lib/python3.5/site-packages/pymc3/distributions/distribution.py in _draw_value(param, point, givens)
#     284                 variables = values = []
#     285             func = _compile_theano_function(param, variables)
# --> 286             return func(*values)
#     287     else:
#     288         raise ValueError('Unexpected type in draw_value: %s' % type(param))
#
# /home/aniruddh/anaconda3/lib/python3.5/site-packages/theano/compile/function_module.py in __call__(self, *args, **kwargs)
#     896                     node=self.fn.nodes[self.fn.position_of_error],
#     897                     thunk=thunk,
# --> 898                     storage_map=getattr(self.fn, 'storage_map', None))
#     899             else:
#     900                 # old-style linkers raise their own exceptions
#
# /home/aniruddh/anaconda3/lib/python3.5/site-packages/theano/gof/link.py in raise_with_op(node, thunk, exc_info, storage_map)
#     323         # extra long error message in that case.
#     324         pass
# --> 325     reraise(exc_type, exc_value, exc_trace)
#     326
#     327
#
# /home/aniruddh/anaconda3/lib/python3.5/site-packages/six.py in reraise(tp, value, tb)
#     683             value = tp()
#     684         if value.__traceback__ is not tb:
# --> 685             raise value.with_traceback(tb)
#     686         raise value
#     687
#
# /home/aniruddh/anaconda3/lib/python3.5/site-packages/theano/compile/function_module.py in __call__(self, *args, **kwargs)
#     882         try:
#     883             outputs =\
# --> 884                 self.fn() if output_subset is None else\
#     885                 self.fn(output_subset=output_subset)
#     886         except Exception:
#
# ValueError: Shape mismatch: A.shape[1] != x.shape[0]
# Apply node that caused the error: CGemv{inplace}(AllocEmpty{dtype='float64'}.0, TensorConstant{1.0}, w1.T, <TensorType(float64, vector)>, TensorConstant{0.0})
# Toposort index: 11
# Inputs types: [TensorType(float64, vector), TensorType(float64, scalar), TensorType(float64, matrix), TensorType(float64, vector), TensorType(float64, scalar)]
# Inputs shapes: [(5,), (), (5, 1751), (11,), ()]
# Inputs strides: [(8,), (), (8, 40), (8,), ()]
# Inputs values: [array([  0.00000000e+000,   4.94065646e-324,   9.88131292e-324,
#          1.48219694e-323,   1.97626258e-323]), array(1.0), 'not shown', 'not shown', array(0.0)]
# Outputs clients: [[Elemwise{Tanh}[(0, 0)](CGemv{inplace}.0)]]
#
# HINT: Re-running with most Theano optimization disabled could give you a back-trace of when this node was created. This can be done with by setting the Theano flag 'optimizer=fast_compile'. If that does not work, Theano optimizations can be disabled with 'optimizer=None'.
# HINT: Use the Theano flag 'exception_verbosity=high' for a debugprint and storage map footprint of this apply node.
